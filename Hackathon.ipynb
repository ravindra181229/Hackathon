# %% [markdown]
# # Hackathon

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport

# %%
df = pd.read_csv("C:\\Users\\snopy\\Favorites\\Downloads\\mu_sigma\\mu_sigma\\Problem statement 1_dataset\\adult.csv")

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.isnull()
# Out:
#          age  workclass  fnlwgt  education  education-num  marital-status  \
# 0      False      False   False      False          False           False
# 1      False      False   False      False          False           False
# 2      False      False   False      False          False           False
# 3      False      False   False      False          False           False
# 4      False      False   False      False          False           False
# ...      ...        ...     ...        ...            ...             ...
# 32556  False      False   False      False          False           False
# 32557  False      False   False      False          False           False
# 32558  False      False   False      False          False           False
# 32559  False      False   False      False          False           False
# 32560  False      False   False      False          False           False
#
#        occupation  relationship   race    sex  capital-gain  capital-loss  \
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# country           0
# salary            0
# dtype: int64

# %%
uniqs = []
for x in df.columns:
    uniqs.append(df[x].value_counts())
    uniqs.append('******')
uniqs
# Out:
# [36    898
#  31    888
#  34    886
#  23    877
#  35    876
#       ...
#  83      6
#  85      3
#  88      3
#  87      1
#  86      1
#  Name: age, Length: 73, dtype: int64,
#  '******',
#   Private             22696
#   Self-emp-not-inc     2541
#   Local-gov            2093
#   ?                    1836
#   State-gov            1298
#   Self-emp-inc         1116
#   Federal-gov           960
#   Without-pay            14
#   Never-worked            7
#  Name: workclass, dtype: int64,
#  '******',
#  164190    13
#  203488    13
#  123011    13
#  113364    12
#  121124    12
#            ..
#  284211     1
#  312881     1
#  177711     1
#  179758     1
#  229376     1
#  Name: fnlwgt, Length: 21648, dtype: int64,
#  '******',
#   HS-grad         10501
#   Some-college     7291
#   Bachelors        5355
#   Masters          1723
#   Assoc-voc        1382
#   11th             1175
#   Assoc-acdm       1067
#   10th              933
#   7th-8th           646
# ...

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week         country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
classes = df['salary']
df.drop(['salary'],axis=1,inplace=True)
df['salary'] = classes

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
col = df.columns
col
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'country', 'salary'],
#       dtype='object')

# %%
uniqs=[]
for x in col:
    uniqs.append(df[x].value_counts())

# %%
uniqs
# Out:
# [36    898
#  31    888
#  34    886
#  23    877
#  35    876
#       ...
#  83      6
#  85      3
#  88      3
#  87      1
#  86      1
#  Name: age, Length: 73, dtype: int64,
#   Private             22696
#   Self-emp-not-inc     2541
#   Local-gov            2093
#   ?                    1836
#   State-gov            1298
#   Self-emp-inc         1116
#   Federal-gov           960
#   Without-pay            14
#   Never-worked            7
#  Name: workclass, dtype: int64,
#  164190    13
#  203488    13
#  123011    13
#  113364    12
#  121124    12
#            ..
#  284211     1
#  312881     1
#  177711     1
#  179758     1
#  229376     1
#  Name: fnlwgt, Length: 21648, dtype: int64,
#   HS-grad         10501
#   Some-college     7291
#   Bachelors        5355
#   Masters          1723
#   Assoc-voc        1382
#   11th             1175
#   Assoc-acdm       1067
#   10th              933
#   7th-8th           646
#   Prof-school       576
#   9th               514
# ...

# %%
pf = ProfileReport(df)

# %%
pf.to_widgets()
# Out:
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
for index,i in enumerate(df.columns):
    print(index,i)
# Out:
# 0 age
# 1 workclass
# 2 fnlwgt
# 3 education
# 4 education-num
# 5 marital-status
# 6 occupation
# 7 relationship
# 8 race
# 9 sex
# 10 capital-gain
# 11 capital-loss
# 12 hours-per-week
# 13 country
# 14 salary

# %%
plt.figure(figsize=(15,10))
df.groupby(['workclass'])['salary'].value_counts().plot(kind="bar")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, confusion_matrix, accuracy_score

# %%
x = df.drop(columns=['salary'])

# %%
y = df['salary']

# %%
Encoder_x = LabelEncoder()
for col in x.columns:
    x[col]=Encoder_x.fit_transform(x[col])
Encoder_y = LabelEncoder()

# %%
x.head()
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   22          7    2671          9             12               4
# 1   33          6    2926          9             12               2
# 2   21          4   14086         11              8               0
# 3   36          4   15336          1              6               2
# 4   11          4   19355          9             12               2
#
#    occupation  relationship  race  sex  capital-gain  capital-loss  \
# 0           1             1     4    1            25             0
# 1           4             0     4    1             0             0
# 2           6             1     4    1             0             0
# 3           6             0     2    1             0             0
# 4          10             5     2    0             0             0
#
#    hours-per-week  country
# 0              39       39
# 1              12       39
# 2              39       39
# 3              39       39
# ...

# %%
y
# Out:
# 0         <=50K
# 1         <=50K
# 2         <=50K
# 3         <=50K
# 4         <=50K
#           ...
# 32556     <=50K
# 32557      >50K
# 32558     <=50K
# 32559     <=50K
# 32560      >50K
# Name: salary, Length: 32561, dtype: object

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=1)

# %%
x_train.head()
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 13474   34          4   17690         11              8               6
# 28958   19          4    5585          9             12               5
# 14735   13          6    8879         14             14               4
# 13215    5          2   17902          9             12               4
# 13460   24          4   10299         12             13               2
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# 13474          10             4     4    0             0             0
# 28958           8             4     2    0             0             0
# 14735          10             3     4    1             0             0
# 13215          10             3     4    0             0             0
# 13460          10             0     4    1             0             0
#
#        hours-per-week  country
# 13474              34       39
# 28958              34       39
# ...

# %%
x_test.head()
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 9646    45          6     200          5              3               6
# 709      1          4   13485          1              6               4
# 7385     8          4    4066          9             12               4
# 16671   16          4   21360         11              8               2
# 21932   19          4   17988          1              6               4
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# 9646            8             1     4    0             0             0
# 709             8             2     4    1             0             0
# 7385            5             3     4    1           115             0
# 16671          10             0     4    1             0             0
# 21932           7             4     4    0             0             0
#
#        hours-per-week  country
# 9646               65       39
# 709                24       39
# ...

# %%
y_test.head()
# Out:
# 9646      <=50K
# 709       <=50K
# 7385       >50K
# 16671     <=50K
# 21932     <=50K
# Name: salary, dtype: object

# %%
y_train.head()
# Out:
# 13474     <=50K
# 28958     <=50K
# 14735     <=50K
# 13215     <=50K
# 13460      >50K
# Name: salary, dtype: object

# %%
# KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
knn_predict = knn.predict(x_test)
accuracy_score(knn_predict,y_test)
# Out:
# 0.7833190025795357

# %%
#Decision_tree
dst_tree = DecisionTreeClassifier()
dst_tree.fit(x_train,y_train)
dst_predict = dst_tree.predict(x_test)
accuracy_score(dst_predict,y_test)
# Out:
# 0.8178356467264464

# %%
#Random_forest
ran_forest = RandomForestClassifier()
ran_forest.fit(x_train,y_train)
ran_forest_predict = ran_forest.predict(x_test)
accuracy_score(ran_forest_predict,y_test)
# Out:
# 0.8605822380542931

# %%
#Gaussian

gau = GaussianNB()
gau.fit(x_train,y_train)
gau_predict = gau.predict(x_test)
accuracy_score(gau_predict,y_test)
# Out:
# 0.8236088932563567

# %%
Y = df['salary']
X1 = df.drop(['salary'],axis=1)

# %%
from sklearn.preprocessing import OneHotEncoder
encode = OneHotEncoder()
X = encode.fit_transform(X1)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,y,test_size=0.25,random_state=1)

# %%
X_train
# Out:
# <24420x22144 sparse matrix of type '<class 'numpy.float64'>'
# 	with 341880 stored elements in Compressed Sparse Row format>

# %%
# KNeighborsClassifier
KNN = KNeighborsClassifier()
KNN.fit(X_train,Y_train)
KNN_predict = KNN.predict(X_test)
accuracy_score(KNN_predict,Y_test)
# Out:
# 0.827171109200344

# %%
#Decision_tree
decision = DecisionTreeClassifier()
decision.fit(X_train,Y_train)
decision_predict = decision.predict(X_test)
accuracy_score(decision_predict,Y_test)
# Out:
# 0.8522294558408058

# %%
#Random_forest
random = RandomForestClassifier()
random.fit(X_train,Y_train)
random_predict = random.predict(X_test)
accuracy_score(random_predict,Y_test)
# Out:
# 0.8576341972730622

# %%
import pickle

# %%
random_forest_model = random

# %%
encodes = encode

# %%
model_name = "Hackathon_model.pkl"
encode_name = "Hackathon_encode.pkl"

model = open(model_name,"wb")
pickle.dump(random_forest_model,model)
encode = open(encode_name,"wb")
pickle.dump(encodes,encode)

model.close()
encode.close()

# %%
model = open("Hackathon_model.pkl",'rb')
model = pickle.load(model)

# %%
encode = open('Hackathon_encode.pkl','rb')
encode = pickle.load(encode)

# %%
X=df.drop(['salary'],axis=1)

# %%
X_encode = encode.transform(X)

# %%
predict = model.predict(X_encode)

# %%
predict
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' >50K'],
#       dtype=object)

# %%
predict[3]
# Out:
# ' <=50K'

# %%
predict[8]
# Out:
# ' >50K'

# %%
predict[78]
# Out:
# ' <=50K'

# %%
predict[1:10]
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ' <=50K', ' <=50K', ' <=50K',
#        ' >50K', ' >50K', ' >50K'], dtype=object)

# %%
predict[45]
# Out:
# ' >50K'
